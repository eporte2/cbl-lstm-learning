# %%
import os
import sys
import re
import multiprocessing


import numpy as np


from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Embedding, LSTM, Dense
from keras.models import Sequential, load_model
from my_DataGenerator import DataGenerator
# Out:
# Using TensorFlow backend.

# %%
cpus = multiprocessing.cpu_count()
batch_size = 32
output_size = 100
hidden_size = 50
epochs = 15
shuffle = False


transcript_dir = ../
model = None

# %%
def get_data_from_files():
    data = []
    for subdir, dirs, files in os.walk(transcript_dir):
        for file in files:
            if ('.capp' in file):
                textfile = subdir+'/'+file
                with open(textfile,'r') as f :
                    lines = f.readlines()
                train = []
                test = []
                for sent in lines :
                    if '*CHI:' in sent :
                        sent = re.sub('\*[A-Z]+: ', '', sent)
                        test.append(sent)
                    else :
                        sent = re.sub('\*[A-Z]+: ', '', sent)
                        train.append(sent)
                data.append((file,train,test))

    return data

# %%
def get_seq_prob(word, context, maxlen):
    global model
    sub_seq = list(context)
    sub_seq.append(word)
    x, y = prepare_seq(sub_seq, maxlen)
    x = np.array(x)
    y = np.array(y) - 1  # The word <PAD> does not have a class

    p_pred = model.predict(x)
    log_p_seq = 0

    for i, prob in enumerate(p_pred):
        prob_word = prob[y[i]]
        log_p_seq += np.log(prob_word)

    return np.exp(log_p_seq)


def eval_production(seq, maxlen):
    result = 0
    vocab = list(seq)
    context = []

    while vocab != [] :
        (next_word, max_prob) = max([(v, get_seq_prob(v, context, maxlen)) for v in vocab], key=lambda prob:prob[1])
        context.append(next_word)
        vocab.remove(next_word)

    if context == seq :
        result = 1

    return result


def get_seq_bylength(seqs) :
    seqs_bylength = dict()
    for seq in seqs :
        seqlen = len(seq)
        if seqlen > 1:
            if seqlen in seqs_bylength:
                seqs_bylength[seqlen].append(seq)
            else :
                seqs_bylength[seqlen] = [seq]
    return seqs_bylength



def get_performance_bylength(seqs_bylength, maxlen) :
    results_bylength = dict()
    for length,seqs in seqs_bylength.items():
        results_bylength[length] = [0, len(seqs)]
        print(str(length))
        for seq in seqs:
            results_bylength[length][0] += eval_production(seq, maxlen)

    return results_bylength

# %%
data = get_data_from_files()

for file,train,test in data:
    print('PREPARE DATA FOR: '+file+'\n')
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(train)

    vocab = tokenizer.word_index
    vocab_size = len(vocab)

    train_seqs = tokenizer.texts_to_sequences(train)
    test_seqs = tokenizer.texts_to_sequences(test)
    train_maxlen = max([len(seq) for seq in train_seqs])
    test_maxlen = max([len(seq) for seq in test_seqs])
    
    steps_per_epoch = ceil(len(train_seqs)/ batch_size)
    validation_steps= ceil(len(test_seqs)/ batch_size)
    
    print('vocab_size = '+str(vocab_size))
    print('maxlen = '+str(maxlen))
    print('INITIALIZE DATA GENERATORS...\n')
    
    train_generator = DataGenerator(seqs = train_seqs,
                                       vocab = vocab, 
                                       vocab_size = vocab_size, 
                                       maxlen = train_maxlen, 
                                       batch_size = batch_size, 
                                       shuffle = shuffle)
    test_generator = DataGenerator(seqs = test_seqs,
                                       vocab = vocab, 
                                       vocab_size = vocab_size, 
                                       maxlen = test_maxlen, 
                                       batch_size = batch_size, 
                                       shuffle = shuffle)
    
    print('TRAINING MODEL...\n')
    
    model = Sequential()
    model.add(Embedding(input_dim = vocab_size+1,  # vocabulary size. Adding an
                                                   # extra element for <PAD> word
                        output_dim = output_size,  # size of embeddings
                        input_length = maxlen-1))  # length of the padded sequences
    model.add(LSTM(hidden_size))
    model.add(Dense(vocab_size, activation='softmax'))
    model.compile('rmsprop', 'categorical_crossentropy')

    # Train network
    model.fit_generator(train_generator, 
                        steps_per_epoch = steps_per_epoch, 
                        epochs = epochs,
                        verbose=2, 
                        validation_data=test_generator, 
                        validation_steps=validation_steps, 
                        validation_freq=epochs, 
                        max_queue_size=10, 
                        workers=cpus, 
                        use_multiprocessing=True, 
                        shuffle=shuffle)
    
    
    
    model.save(str('../../models/'+file.split('.capp')[0]+'_model.h5'))
    #model = load_model('Adam_model.h5')
    seqs_bylength = get_seq_bylength(test_seqs)
    print('CALCULATING PRODUCTION PERFORMANCE...\n')
    results = get_performance_bylength(seqs_bylength, test_maxlen)

# %%
###########################################

# %%
file = data[0][0]
train = data[0][1]
test = data[0][2]

# %%
# Out:
# ['play checkers .\n',
#  'big drum .\n',
#  'big drum .\n',
#  'big drum .\n',
#  'big drum .\n',
#  'horse .\n',
#  'who that ?\n',
#  'two check .\n',
#  'rig horn .\n',
#  'yeah .\n',
#  'play checkers .\n',
#  'choochoo train .\n',
#  'yep .\n',
#  'dere water .\n',
#  'big horn .\n',
#  'water right dere .\n',
#  'water .\n',
#  'alright look tv .\n',
#  'Jack Jill come .\n',
#  'part .\n',
#  'part .\n',
#  'Jack Jill .\n',
#  'part .\n',
#  'part .\n',
#  'part .\n',
#  'take suitcase ?\n',
#  'get over Mommy .\n',
#  'nickel .\n',
#  'here Urler .\n',
#  'nickel .\n',
#  'nickel .\n',
#  'nickel .\n',
#  'dont Adam foot .\n',
#  'shadow .\n',
#  'shadow .\n',
#  'shadow .\n',
#  'shadow .\n',
#  'yeah shadow yeah .\n',
#  'shadow funny .\n',
#  'put dirt up .\n',
#  'I Adam dont sit Adam foot .\n',
#  'book .\n',
#  'read book .\n',
#  'put dirt up .\n',
#  'see what bear ?\n',
#  'put dirt up .\n',
#  'upsadaisy .\n',
#  'see marching bear go ?\n',
#  'sit dere .\n',
#  'sit dere .\n',
#  'up upsadaisy .\n',
#  'sit dere .\n',
#  'where book ?\n',
#  'what dat ?\n',
#  'read Shadow .\n',
#  'what dat ?\n',
#  'read Shadow .\n',
#  'what dat ?\n',
#  'sitting chair .\n',
#  'read Shadow .\n',
#  'drop bean .\n',
#  'string string .\n',
#  'drop bean .\n',
#  'drop bean .\n',
#  'tape .\n',
#  'Adam checker .\n',
#  'what dat ?\n',
#  'checker .\n',
#  'what dat ?\n',
#  'horn .\n',
#  'horse .\n',
#  'that screw .\n',
#  'read book .\n',
#  'Ursula all set ?\n',
#  'read Papa bear .\n',
#  'yeah .\n',
#  'I got horn .\n',
#  'put top ?\n',
#  'look .\n',
#  'put top ?\n',
#  'like it hm ?\n',
#  'like Bambi .\n',
#  'do like it .\n',
#  'hurry hurry .\n',
#  'my Shadow .\n',
#  'running .\n',
#  'my Shadow Mommy .\n',
#  'okay .\n',
#  'bunnyrabbit rabbit running .\n',
#  'my suitcase .\n',
#  'be out a way ?\n',
#  'what dat ?\n',
#  'read Shadow .\n',
#  'tooman suitcase .\n',
#  'who that ?\n',
#  'spaghetti .\n',
#  'horse .\n',
#  'oh no no xxx screw part machine .\n',
#  'what happens .\n',
#  'stick you .\n',
#  'Monroe suitcase .\n',
#  'horse go Mommy .\n',
#  'what dat ?\n',
#  'find dirt .\n',
#  'horse .\n',
#  'Mott apple juice .\n',
#  'dat a screw .\n',
#  'Mott apple juice .\n',
#  'get back .\n',
#  'huh ?\n',
#  'spaghetti .\n',
#  'Mott apple juice .\n',
#  'xxx dancing .\n',
#  'spaghetti yeah .\n',
#  'dog bit me bit me dog .\n',
#  'hot .\n',
#  'read book .\n',
#  'dont dog .\n',
#  'yeah ?\n',
#  'bitten me dog nineteen twelve .\n',
#  'no ?\n',
#  'hot ?\n',
#  'no .\n',
#  'look .\n',
#  'hot ?\n',
#  'pencil .\n',
#  'water Mommy .\n',
#  'hot ?\n',
#  'paper Urler .\n',
#  'Mott apple juice .\n',
#  'hot ?\n',
#  'no .\n',
#  'Adam glove .\n',
#  'oh no xxx what dat ?\n',
#  'need one ?\n',
#  'Adam glove .\n',
#  'huh ?\n',
#  'put ball .\n',
#  'not tv not tv .\n',
#  'read book .\n',
#  'put ball .\n',
#  'who that ?\n',
#  'Adam need one .\n',
#  'no find you penny .\n',
#  'put the ball .\n',
#  'who that ?\n',
#  'come Cromer ?\n',
#  'what happen Mommy ?\n',
#  'where dat come from ?\n',
#  'penny yeah .\n',
#  'no .\n',
#  'who that ?\n',
#  'Daddy Cromer paper .\n',
#  'tape recorder .\n',
#  'who that Daddy ?\n',
#  'piece paper .\n',
#  'train track .\n',
#  'whos that ?\n',
#  'put it pocket .\n',
#  'put the ball .\n',
#  'piece .\n',
#  'two three .\n',
#  'piece paper .\n',
#  'oh yes .\n',
#  'what dat ?\n',
#  'poor Urler .\n',
#  'oh yes .\n',
#  'big horn .\n',
#  'what dat ?\n',
#  'horn .\n',
#  'd nine ten .\n',
#  'put ball over here .\n',
#  'what dat ?\n',
#  'two three four .\n',
#  'd nine ten .\n',
#  'other one .\n',
#  'what dat from ?\n',
#  'eight nine ten eleven two fourteen four cowboy .\n',
#  'hit Mommy wall .\n',
#  'touch other one .\n',
#  'poor Cromer .\n',
#  'hole in there ?\n',
#  'd nine .\n',
#  'nine two three ten eleven nine one dis .\n',
#  'four four four .\n',
#  'my mine .\n',
#  'license number .\n',
#  'hit Mommy rug .\n',
#  'what dat ?\n',
#  'no .\n',
#  'd .\n',
#  'take two .\n',
#  'pipe .\n',
#  'one two three .\n',
#  'number .\n',
#  'pad .\n',
#  'who that ?\n',
#  'mine .\n',
#  'hi .\n',
#  'one for you .\n',
#  'd a number .\n',
#  'put record .\n',
#  'what dat ?\n',
#  'take a glove .\n',
#  'rug .\n',
#  'have a pencil .\n',
#  'yellow Mommy .\n',
#  'where ball ?\n',
#  'put record ?\n',
#  'take a button off .\n',
#  'tape recorder .\n',
#  'go dere ?\n',
#  'okay ?\n',
#  'Adam horn .\n',
#  'tiger .\n',
#  'piece paper Mommy ?\n',
#  'where ball go ?\n',
#  'go dere ?\n',
#  'Adam horn hm hm ?\n',
#  'what shell doing ?\n',
#  'no no xxx want pencil .\n',
#  'go dere ?\n',
#  'there we go Cromer .\n',
#  'hungry .\n',
#  'checking clock .\n',
#  'my pencil my .\n',
#  'in there ?\n',
#  'what doing ?\n',
#  'want ta what take .\n',
#  'read story ?\n',
#  'read book ?\n',
#  'what you doing ?\n',
#  'go dere ?\n',
#  'bath ?\n',
#  'read Catherine ?\n',
#  'in there ?\n',
#  'make noise .\n',
#  'Daddy go ?\n',
#  'hungry .\n',
#  'huh ?\n',
#  'where go ?\n',
#  'choochoo train .\n',
#  'Adam go get it .\n',
#  'one Mommy .\n',
#  'here are Cromer .\n',
#  'where go ?\n',
#  'what dat ?\n',
#  'one Daddy .\n',
#  'choochoo train .\n',
#  'write Cromer .\n',
#  'here are .\n',
#  'jelly .\n',
#  'write dat Cromer .\n',
#  'choochoo train .\n',
#  'dat ?\n',
#  'what dat ?\n',
#  'choochoo train .\n',
#  'get stuck .\n',
#  'theres a Cromer .\n',
#  'write Urler .\n',
#  'what dat for ?\n',
#  'choochoo train .\n',
#  'Adam get stuck .\n',
#  'want ta see pictures ?\n',
#  'write Adam .\n',
#  'jelly Mommy .\n',
#  'choochoo train .\n',
#  'bye see later again .\n',
#  'write Perro .\n',
#  'draw MickeyMouse pop .\n',
#  'dis a other one .\n',
#  'choochoo train .\n',
#  'what dat ?\n',
#  'see .\n',
#  'Daddy car .\n',
#  'come on .\n',
#  'happen ?\n',
#  'pen Cromer .\n',
#  'what dat ?\n',
#  'carry buffalo .\n',
#  'happen paper ?\n',
#  'draw b a o .\n',
#  'here Cromer .\n',
#  'you right hand .\n',
#  'choochoo train .\n',
#  'dat .\n',
#  'happen ?\n',
#  'what dat ?\n',
#  'carry buffalo .\n',
#  'Adam ball .\n',
#  'dat very pretty ?\n',
#  'who dat ?\n',
#  'look Mommy .\n',
#  'dat .\n',
#  'very pretty .\n',
#  'tootoo train ?\n',
#  'Daddy ?\n',
#  'dere other side .\n',
#  'kangaroo .\n',
#  'what dat ?\n',
#  'car .\n',
#  'Daddy Daddy Daddy .\n',
#  'write Cromer .\n',
#  'car .\n',
#  'dats a my pencil .\n',
#  'train track ?\n',
#  'yeah haha .\n',
#  'kangaroo .\n',
#  'mine mine mine mine .\n',
#  'see ?\n',
#  'what dat Mommy ?\n',
#  'train track ?\n',
#  'what happen .\n',
#  'like some ?\n',
#  'dats a other one .\n',
#  'read dat train track .\n',
#  'red yellow .\n',
#  'circus .\n',
#  'look it dat .\n',
#  'red yellow .\n',
#  'truck .\n',
#  'tell Urler .\n',
#  'yellow yellow yellow .\n',
#  'train train .\n',
#  'another one truck .\n',
#  'write dat piece a paper .\n',
#  'sit in Adam chair .\n',
#  'oh cow .\n',
#  'Adam sit down book .\n',
#  'another one .\n',
#  'oh cow baby pig .\n',
#  'Adam right dere .\n',
#  'train .\n',
#  'write .\n',
#  'Adam drop it train .\n',
#  'no .\n',
#  'no baby pig .\n',
#  'write someping .\n',
#  'come from ?\n',
#  'no over .\n',
#  'dat a handle .\n',
#  'Adam sit .\n',
#  'what dat ?\n',
#  'write Cromer .\n',
#  'choochoo train .\n',
#  'thats a wite .\n',
#  'taper ?\n',
#  'hand me piece a paper .\n',
#  'there boots dog .\n',
#  'drop it choochoo train .\n',
#  'wite wite .\n',
#  'next a Mommy .\n',
#  'wash hand .\n',
#  'choochoo train .\n',
#  'a wite wite wite baby pig ?\n',
#  'I wash hand .\n',
#  'want ta next Mommy .\n',
#  'please .\n',
#  'come from taper ?\n',
#  'yep .\n',
#  'who that ?\n',
#  'choochoo train .\n',
#  'who that Daddy ?\n',
#  'put dat in there ?\n',
#  'choochoo train .\n',
#  'give me mine pen .\n',
#  'baby pig yeah .\n',
#  'what dat ?\n',
#  'oh no hurt .\n',
#  'who that ?\n',
#  'train .\n',
#  'come from ?\n',
#  'who that Daddy ?\n',
#  'tape recorder hurt .\n',
#  'train coming .\n',
#  'come from for ?\n',
#  'get a hand out .\n',
#  'car .\n',
#  'train track .\n',
#  'screwdriver hurt .\n',
#  'go walking .\n',
#  'come from ?\n',
#  'truck .\n',
#  'Cathy .\n',
#  'for mine .\n',
#  'hand me piece a paper .\n',
#  'ow .\n',
#  'come from for ?\n',
#  'maybe cow .\n',
#  'house house house .\n',
#  'there .\n',
#  'for mine Mommy .\n',
#  'next me .\n',
#  'green box .\n',
#  'moo cow .\n',
#  'who is that ?\n',
#  'step book .\n',
#  'house Mommy .\n',
#  'I want to sit next .\n',
#  'green .\n',
#  'book .\n',
#  'horn .\n',
#  'diesel motor no no motor .\n',
#  'fix screwdriver .\n',
#  'yeah .\n',
#  'build house .\n',
#  'yeah .\n',
#  'dat box .\n',
#  'what dat ?\n',
#  'need a another one .\n',
#  'yellow too .\n',
#  'get open .\n',
#  'too .\n',
#  'baggage car .\n',
#  'what dat ?\n',
#  'need a another one .\n',
#  'open Mommy .\n',
#  'build another one .\n',
#  'Cromer hi .\n',
#  'show write .\n',
#  'go fall .\n',
#  'yellow .\n',
#  'no no fall no .\n',
#  'dat a Alvin .\n',
#  'streamline coach .\n',
#  'who dat ?\n',
#  'screw firetruck ?\n',
#  'oh cup .\n',
#  'no fall .\n',
#  'dat Cromer Ursula Cromer .\n',
#  'screw .\n',
#  'busy bulldozer .\n',
#  'yyy car .\n',
#  'huh ?\n',
#  'build another house .\n',
#  'red .\n',
#  'walk busy bulldozer .\n',
#  'Alvin .\n',
#  'go dere ?\n',
#  'dining car .\n',
#  'what dat ?\n',
#  'string string .\n',
#  'Cromer .\n',
#  'put this one Mommy .\n',
#  'street light .\n',
#  'two .\n',
#  'what de getting ears ?\n',
#  'huh ?\n',
#  'more ?\n',
#  'cork .\n',
#  'there bunnyrabbit .\n',
#  'motor .\n',
#  'yeah .\n',
#  'taking ears .\n',
#  'just like xxx .\n',
#  'what dat ?\n',
#  'come on bunnyrabbit .\n',
#  'finished .\n',
#  'awoh xxx .\n',
#  'looking for ?\n',
#  'what de taking ears ?\n',
#  'lion .\n',
#  'where go ?\n',
#  'beetle beetle beetle .\n',
#  'saggy baggy elephant .\n',
#  'do it .\n',
#  'hungry .\n',
#  'oh .\n',
#  'train right dere .\n',
#  'mine .\n',
#  'hit ball .\n',
#  'okay do it .\n',
#  'my paper .\n',
#  'what de taking ears ?\n',
#  'put together .\n',
#  'okay ?\n',
#  'oh oh oh .\n',
#  'mine .\n',
#  'snow plow .\n',
#  'saggy baggy elephant .\n',
#  'oh no put together .\n',
#  'looking for .\n',
#  'okay .\n',
#  'xxx big one beetle .\n',
#  'tickle ears ?\n',
#  'a bunnyrabbit walk .\n',
#  'color ?\n',
#  'do it .\n',
#  'lost a piggie .\n',
#  'show you ?\n',
#  'flat car .\n',
#  'red red .\n',
#  'looking for Cromer .\n',
#  'where my pen Ursula ?\n',
#  'dats a face .\n',
#  'white .\n',
#  'mail car .\n',
#  'red right dere .\n',
#  'dats a Cromer face .\n',
#  'I do it .\n',
#  'big one .\n',
#  'dats a Perry .\n',
#  'yes yes yes .\n',
#  'truck .\n',
#  'tank car .\n',
#  'okay do it .\n',
#  'hop hop hop .\n',
#  'beetle .\n',
#  'pen .\n',
#  'hurt truck .\n',
#  'what dat ?\n',
#  'Cromer .\n',
#  'around .\n',
#  'okay .\n',
#  'what xxx drawing ?\n',
#  'hurt truck .\n',
#  'what dat ?\n',
#  'let me slip down .\n',
#  'box car .\n',
#  'Perry .\n',
#  'find him ?\n',
#  'what you drawing ?\n',
#  'sweep broom .\n',
#  'turn around .\n',
#  'piece of paper .\n',
#  'here we are .\n',
#  'yep .\n',
#  'caboose .\n',
#  'let me open it ?\n',
#  'truck .\n',
#  'grandfather .\n',
#  'car broken .\n',
#  'no .\n',
#  'I caught it .\n',
#  'puppy .\n',
#  'truck broken Mommy .\n',
#  'pen Ursula ?\n',
#  'xxx coming .\n',
#  'yeah .\n',
#  'let me go round .\n',
#  'dont crying .\n',
#  'upsadaisy caught it .\n',
#  'puppy dog .\n',
#  'went grocery store .\n',
#  'yep .\n',
#  'dripping down Mommy .\n',
#  'give dat Cromer .\n',
#  'dont crying Ursula .\n',
#  'man .\n',
#  'kitty .\n',
#  'didnt ?\n',
#  'okay ?\n',
#  'this is heavy .\n',
#  'hit Ursula .\n',
#  'go dere Mommy ?\n',
#  'here Cromer .\n',
#  'okay ?\n',
#  'didnt no .\n',
#  'saggy baggy doesnt eat a all up .\n',
#  'egg .\n',
#  'dis one ?\n',
#  'spank .\n',
#  'seal .\n',
#  'I put truck .\n',
#  'little seed .\n',
#  'at the mouth .\n',
#  'you take candy .\n',
#  'I get that brush that brush .\n',
#  'move seal move .\n',
#  'poor Ursula .\n',
#  'get candy mouth .\n',
#  'move .\n',
#  'go car .\n',
#  'little seed .\n',
#  'yes .\n',
#  'oh no .\n',
#  'move .\n',
#  'hi BunnyRabbit .\n',
#  'what else ?\n',
#  'go dere Mommy ?\n',
#  'a writing ?\n',
#  'egg eat .\n',
#  'get truck .\n',
#  'no .\n',
#  'Cromer Cromer Cromer Cromer .\n',
#  'xxx put baby .\n',
#  'let me .\n',
#  'let me eat .\n',
#  'my screwdriver .\n',
#  'seal .\n',
#  'my busy bulldozer truck .\n',
#  'put it down .\n',
#  'pretty Mommy ?\n',
#  'eat xxx icecream .\n',
#  'strong MickeyMouse .\n',
#  'hi bunnyrabbit Adam Smith .\n',
#  'you going faster ?\n',
#  'what about Adam writing ?\n',
#  'yes .\n',
#  'strong MickeyMouse .\n',
#  'show Mommy .\n',
#  'went a car .\n',
#  'dats right .\n',
#  'put baby .\n',
#  'oh somebody write dat .\n',
#  'Adam ate candy .\n',
#  'busy bulldozer .\n',
#  'one one one pretty ?\n',
#  'who dat ?\n',
#  'not ?\n',
#  'truck look .\n',
#  'dont know .\n',
#  'dat a road paper .\n',
#  'washer .\n',
#  'cold .\n',
#  'no .\n',
#  'who did ?\n',
#  'baby .\n',
#  'let me at .\n',
#  'animal .\n',
#  'over Mommy ?\n',
#  'get light .\n',
#  'hi want to talk tunnel .\n',
#  'what it ?\n',
#  'wet .\n',
#  'oh no busy bulldozer .\n',
#  'where penny go ?\n',
#  'MickeyMouse .\n',
#  'Adam icecream .\n',
#  'what else ?\n',
#  'airplane .\n',
#  'look it dat page .\n',
#  'get light .\n',
#  'drop it Mommy .\n',
#  'big doggie eating .\n',
#  'snowing Cromer .\n',
#  'airplane .\n',
#  'want me open ?\n',
#  'write Adam Smith .\n',
#  'get light .\n',
#  'write pencil .\n',
#  'xxx go in there ?\n',
#  'you wet ?\n',
#  'give a one Cromer .\n',
#  'Perro off .\n',
#  'dat busy bulldozer truck .\n',
#  'okay .\n',
#  'going go around little ?\n',
#  'get light .\n',
#  'big dog eating .\n',
#  'give a one Cromer .\n',
#  'Adam do it .\n',
#  'busy bulldozer truck .\n',
#  'write xxx penguin .\n',
#  'see penny .\n',
#  'Mommy ?\n',
#  'street light .\n',
#  'bit .\n',
#  'last night glue .\n',
#  'get light .\n',
#  'alright .\n',
#  'okay Cromer .\n',
#  'what is what de in there ?\n',
#  'two busy bulldozer .\n',
#  'street light .\n',
#  'penguin .\n',
#  'Perro alright .\n',
#  'egg .\n',
#  'where Momma ?\n',
#  'street light .\n',
#  'red yellow .\n',
#  'no ?\n',
#  'egg apple .\n',
#  'take dis ?\n',
#  'penguin .\n',
#  'bed .\n',
#  'red yellow .\n',
#  'street light .\n',
#  'yep .\n',
#  'Adam write penguin .\n',
#  'big a Perro .\n',
#  'hahaha .\n',
#  'here have pen ?\n',
#  'what you doing ?\n',
#  'look .\n',
#  'glue .\n',
#  'yes .\n',
#  'oh drop it Mommy .\n',
#  'top .\n',
#  'penguin .\n',
#  'look .\n',
#  'Christmas .\n',
#  'hoho ho .\n',
#  'potato potato potato potato .\n',
#  'glue .\n',
#  'pocket ?\n',
#  'knock over .\n',
#  'look .\n',
#  'put a back .\n',
#  'dis ?\n',
#  'dis one ?\n',
#  'write cowboy .\n',
#  'yeah .\n',
#  'Urler right dere yellow .\n',
#  'dey are two them .\n',
#  'sleeping car .\n',
#  'apple drop .\n',
#  'put it up dere Mommy .\n',
#  'potato .\n',
#  'call animal .\n',
#  'glue yes .\n',
#  'hear tractor .\n',
#  'look it dat cowboy .\n',
#  'yeah funny .\n',
#  'truck .\n',
#  'Adam did .\n',
#  'Urler right dere .\n',
#  'go over .\n',
#  'just like Adam truck .\n',
#  'who dat ?\n',
#  'potato yeah .\n',
#  'tatoo man miss it .\n',
#  'zoo ?\n',
#  'egg .\n',
#  'where penny go ?\n',
#  'truck go ?\n',
#  'parrot .\n',
#  'Christmas .\n',
#  'dats a Cromer pencil .\n',
#  'I playing Ursula .\n',
#  'put together again .\n',
#  'dining where eat .\n',
#  'turkey pine .\n',
#  'egg .\n',
#  'booking .\n',
#  'doggie .\n',
#  'who dat .\n',
#  'no .\n',
#  'yep .\n',
#  'saggy baggy .\n',
#  'drop it .\n',
#  'turkey pine .\n',
#  'booking booking booking booking .\n',
#  'picture on other one .\n',
#  'Ursula .\n',
#  'let Adam xxx .\n',
#  'doggie right dere .\n',
#  'box car .\n',
#  'see truck Mommy .\n',
#  'what dat noise ?\n',
#  'put together Mommy .\n',
#  'I driving tricycle .\n',
#  'look like Adam truck .\n',
#  'parrot .\n',
#  'turkey pine .\n',
#  'pull to .\n',
#  'see truck .\n',
#  'cowboy too .\n',
#  'what dat .\n',
#  'what else ?\n',
#  'hot .\n',
#  'write .\n',
#  'man .\n',
#  'let Adam write .\n',
#  'noise .\n',
#  'turn over .\n',
#  'yes .\n',
#  'no Pluto .\n',
#  'xxx roadgrader .\n',
#  'booking booking .\n',
#  'I sorry .\n',
#  'what happen Mommy ?\n',
#  'excuse please .\n',
#  'xxx look somebody .\n',
#  'car .\n',
#  'no I see truck .\n',
#  'egg .\n',
#  'tease book tease .\n',
#  'I sorry .\n',
#  'lamb .\n',
#  'I xxx some .\n',
#  'look like Adam car .\n',
#  'I sorry Cromer .\n',
#  'excuse please .\n',
#  'down .\n',
#  'tease .\n',
#  'anything you .\n',
#  'no .\n',
#  'baa baa baa .\n',
#  'where is it ?\n',
#  'I sorry write .\n',
#  'tease .\n',
#  'what dat come from ?\n',
#  'dats a Cromer .\n',
#  'huh ?\n',
#  'yes .\n',
#  'too tiny .\n',
#  'excuse please .\n',
#  'somebody pocketbook .\n',
#  'Adam did .\n',
#  'what happen Mommy ?\n',
#  'oh punching ball pop .\n',
#  'hi Cromer .\n',
#  'somebody .\n',
#  'around .\n',
#  'Adam did .\n',
#  'where is it ?\n',
#  'tease tease .\n',
#  'what dat some ?\n',
#  'yeah .\n',
#  'Ursla .\n',
#  'see other one put together .\n',
#  'turn round .\n',
#  'drop it .\n',
#  'like dis ?\n',
#  'there go one .\n',
#  'doggie doggie doggie .\n',
#  'dere Adam made that .\n',
#  'play xxx dat train Cromer ?\n',
#  'my pencil .\n',
#  'go get it .\n',
#  'turn it around ?\n',
#  'teasing teasing teasing .\n',
#  'dont fall .\n',
#  'see other one .\n',
#  'men .\n',
#  'big a doggie .\n',
#  'Adam made that .\n',
#  'doesnt fall .\n',
#  'drop .\n',
#  'play xxx Cromer play ?\n',
#  'excuse me Cromer .\n',
#  'xxx busy bulldozer .\n',
#  'see a truck .\n',
#  'Adam made that .\n',
#  'teasing .\n',
#  'awoh .\n',
#  'sardine .\n',
#  'dat one .\n',
#  'open dat .\n',
#  'big doggie eat big doggie eat .\n',
#  'dis came .\n',
#  'doggie want to write ?\n',
#  'play dat ?\n',
#  'see truck Mommy .\n',
#  'doing going round .\n',
#  'window drop .\n',
#  'dere Cromer .\n',
#  'see other one .\n',
#  'dat a Cromer Cromer house .\n',
#  'open Mommy ?\n',
#  'teasing .\n',
#  'see truck .\n',
#  'play peekaboo .\n',
#  'look like egg .\n',
#  'mail car .\n',
#  'see other one .\n',
#  'doggie want to write ?\n',
#  'tease a Cromer .\n',
#  'push dat ?\n',
#  'sarbaby ?\n',
#  'hammer ?\n',
#  'truck .\n',
#  'look .\n',
#  'see other one .\n',
#  'have play peekaboo .\n',
#  'put truck Mommy .\n',
#  'stop car .\n',
#  'sardines .\n',
#  'want ta play tractor ?\n',
#  'look .\n',
#  'see other one .\n',
#  'there ?\n',
#  'do it again ?\n',
#  'want ta bite dat ?\n',
#  'lets see .\n',
#  'want me open it ?\n',
#  'another one .\n',
#  'car .\n',
#  'sardine .\n',
#  'okay .\n',
#  'put truck window .\n',
#  'lets see .\n',
#  'one .\n',
#  'xxx Adam mouth .\n',
#  'turkey pine .\n',
#  'go home .\n',
#  'lets see .\n',
#  'look like hammer .\n',
#  'two .\n',
#  'boo .\n',
#  'what this is car .\n',
#  'blow nose ?\n',
#  'who did ?\n',
#  'lets see .\n',
#  'cow boy .\n',
#  'oh oh .\n',
#  'truck .\n',
#  'who did that ?\n',
#  'want ta put .\n',
#  'blow nose ?\n',
#  'look like dat .\n',
#  'I jackinthebox funny .\n',
#  'come with that .\n',
#  'what dat ?\n',
#  'want to have the balls want to ?\n',
#  'Cromer .\n',
#  'look tow truck come here .\n',
#  'yeah .\n',
#  'I jackinthebox .\n',
#  'what dat is dat Cromer ?\n',
#  'hammer .\n',
#  'pin .\n',
#  'turkey pine turkey pine .\n',
#  'tank car .\n',
#  'fourteen pinwheel .\n',
#  'no .\n',
#  'come with that .\n',
#  'who did ?\n',
#  'street light .\n',
#  'put block in in there .\n',
#  'yeah Mommy pin .\n',
#  'street light .\n',
#  'who did Mommy ?\n',
#  'dont dont want have lunch .\n',
#  'on the floor .\n',
#  'look like one .\n',
#  'blow nose ?\n',
#  'turkey .\n',
#  'yeah .\n',
#  'dog .\n',
#  'put de block in there .\n',
#  'turkey pie .\n',
#  'who did ?\n',
#  'right dere .\n',
#  'Christmas .\n',
#  'doggie .\n',
#  'toy train .\n',
#  'look .\n',
#  'turkey pine turkey pine .\n',
#  'car .\n',
#  'other foot .\n',
#  'horn ?\n',
#  'dog have hole .\n',
#  'I miss it .\n',
#  'street light fire hydrant .\n',
#  'look Mommy .\n',
#  'call tootoo train .\n',
#  'Adam did .\n',
#  'yeah .\n',
#  'yes .\n',
#  'yeah .\n',
#  'put de trash can .\n',
#  'where doggie go ?\n',
#  'come out Mommy .\n',
#  'have sandwich too .\n',
#  'flower .\n',
#  'pine turkey .\n',
#  'cowboy xxx lotsof boot .\n',
#  'Adam horn .\n',
#  'dingdong bell .\n',
#  'pinwheel pushing .\n',
#  'red car .\n',
#  'let me have one .\n',
#  'call caboose .\n',
#  'doggie ?\n',
#  'I put de trash can .\n',
#  'where penny go ?\n',
#  'busy bulldozer .\n',
#  'what in there ?\n',
#  'xxx sandwich too .\n',
#  'paper .\n',
#  'show something broke .\n',
#  'pushing door .\n',
#  'there find .\n',
#  'just pretend dont .\n',
#  'squeak ?\n',
#  'I drink it milk .\n',
#  'yeah .\n',
#  'yellow car .\n',
#  'doggie Mommy ?\n',
#  'take out .\n',
#  'caboose .\n',
#  'squeak ?\n',
#  'yeah .\n',
#  'what dat Ursula what dat ?\n',
#  'yeah .\n',
#  'take out .\n',
#  'red .\n',
#  'two t Mama doing .\n',
#  'there go another one .\n',
#  'derrick .\n',
#  'door .\n',
#  'its not fit .\n',
#  'tired .\n',
#  'dere coffee broken .\n',
#  'find penny .\n',
#  'take paper off .\n',
#  'big needle .\n',
#  'what dat ?\n',
#  ...]

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train+test)

vocab = tokenizer.word_index
vocab_size = len(vocab)

train_seqs = tokenizer.texts_to_sequences(train)
test_seqs = tokenizer.texts_to_sequences(test)


training_generator = DataGenerator(train_seqs, vocab, maxlen, **params)
validation_generator = DataGenerator(partition['validation'], labels, **params)


vocab_size,maxlen,x,y = prepare_train_set(train_seqs)
g_model = load_model('../../../../Adam_model.h5')

# %%
seqs_bylength = get_seq_bylength(test_seqs)

# %%
seqs_bylength
# Out:
# {2: [[66, 2017],
#   [91, 502],
#   [91, 502],
#   [91, 502],
#   [91, 502],
#   [77, 13],
#   [62, 1007],
#   [4085, 567],
#   [66, 2017],
#   [663, 145],
#   [63, 136],
#   [91, 567],
#   [813, 1510],
#   [65, 415],
#   [54, 598],
#   [471, 184],
#   [179, 191],
#   [172, 63],
#   [172, 63],
#   [43, 441],
#   [172, 63],
#   [38, 191],
#   [5, 11],
#   [179, 471],
#   [5, 11],
#   [179, 471],
#   [5, 11],
#   [436, 238],
#   [179, 471],
#   [220, 604],
#   [469, 469],
#   [220, 604],
#   [220, 604],
#   [29, 3351],
#   [5, 11],
#   [5, 11],
#   [13, 425],
#   [179, 191],
#   [22, 235],
#   [22, 235],
#   [25, 584],
#   [1812, 1812],
#   [31, 471],
#   [31, 415],
#   [5, 11],
#   [179, 471],
#   [1247, 415],
#   [77, 13],
#   [5, 411],
#   [390, 1],
#   [1916, 415],
#   [5, 11],
#   [188, 398],
#   [52, 81],
#   [58, 804],
#   [788, 44],
#   [179, 191],
#   [14, 266],
#   [136, 18],
#   [118, 598],
#   [29, 721],
#   [103, 17],
#   [29, 721],
#   [22, 170],
#   [179, 191],
#   [22, 170],
#   [77, 13],
#   [77, 13],
#   [101, 129],
#   [662, 44],
#   [77, 13],
#   [222, 401],
#   [239, 118],
#   [354, 354, 354],
#   [93, 17, 113],
#   [29, 67, 63],
#   [9, 182, 738],
#   [11, 3, 986],
#   [42, 3, 2152],
#   [51, 511, 266],
#   [546, 3, 18],
#   [2, 501, 249],
#   [101, 150, 807],
#   [77, 13, 130],
#   [182, 738, 44],
#   [24, 9, 194],
#   [77, 13, 130],
#   [222, 401, 194],
#   [101, 150, 41],
#   [101, 150, 41],
#   [157, 157, 157],
#   [41, 196, 18],
#   [77, 8, 13],
#   [650, 93, 17],
#   [11, 3, 1862],
#   [650, 93, 157],
#   [280, 290, 281],
#   [79, 25, 58],
#   [101, 15, 943],
#   [1511, 1511, 1511],
#   [1576, 1339, 492],
#   [145, 67, 63],
#   [84, 10, 4],
#   [24, 24, 24],
#   [1576, 1339, 492],
#   [3, 943, 280],
#   [376, 3, 887],
#   [247, 41, 129],
#   [106, 3, 370],
#   [244, 67, 63],
#   [2, 10, 4],
#   [106, 3, 2628],
#   [32, 32, 32],
#   [84, 10, 4],
#   [944, 944, 944],
#   [5, 58, 769],
#   [5, 1, 769],
#   [239, 46, 118],
#   [54, 56, 37],
#   [2, 371, 4],
#   [113, 217, 18],
#   [441, 371, 4],
#   [213, 1341, 639],
#   [1884, 59, 18],
#   [134, 11, 129],
#   [14, 565, 95],
#   [48, 8, 576],
#   [34, 63, 18],
#   [2, 22, 113],
#   [86, 6, 225],
#   [1, 65, 912],
#   [279, 526, 279],
#   [52, 912, 225],
#   [34, 63, 18],
#   [58, 22, 182],
#   [88, 21, 125],
#   [22, 4, 59],
#   [125, 58, 640],
#   [1, 27, 1451],
#   [213, 3, 111],
#   [29, 814, 912],
#   [88, 21, 86],
#   [38, 662, 34],
#   [220, 4, 18],
#   [91, 163, 549],
#   [20, 21, 146],
#   [121, 29, 518],
#   [91, 266, 549],
#   [29, 10, 4],
#   [290, 281, 113],
#   [121, 58, 1168],
#   [610, 437, 888],
#   [62, 290, 281],
#   [29, 121, 1168],
#   [91, 3, 445],
#   [54, 23, 341],
#   [5, 1, 110],
#   [22, 3, 81],
#   [598, 67, 63],
#   [38, 662, 34],
#   [2, 208, 95],
#   [22, 251, 140],
#   [1128, 38, 125],
#   [88, 29, 58],
#   [163, 67, 63],
#   [26, 113, 18],
#   [5, 11, 338],
#   [22, 251, 18],
#   [2, 594, 616],
#   [88, 29, 121],
#   [5, 245, 18],
#   [58, 55, 257],
#   [2002, 191, 2002],
#   [2, 58, 33],
#   [2, 464, 129],
#   [2148, 2148, 2148],
#   [38, 8, 4],
#   [2, 464, 121],
#   [106, 3, 129],
#   [5, 245, 18],
#   [38, 8, 4],
#   [5, 11, 33],
#   [51, 34, 17],
#   [163, 163, 163],
#   [34, 52, 4],
#   [94, 4, 167],
#   [1886, 1886, 1886],
#   [26, 128, 17],
#   [91, 3, 163],
#   [29, 192, 13],
#   [454, 21, 129],
#   [58, 290, 281],
#   [26, 3, 113],
#   [29, 192, 13],
#   [26, 113, 18],
#   [110, 27, 300],
#   [26, 128, 17],
#   [55, 25, 494],
#   [26, 128, 17],
#   [2002, 3, 129],
#   [26, 128, 17],
#   [23, 66, 559],
#   [22, 113, 18],
#   [26, 128, 17],
#   [10, 4, 140],
#   [22, 113, 548],
#   [58, 29, 225],
#   [55, 25, 472],
#   [77, 45, 13],
#   [20, 164, 22],
#   [55, 25, 11],
#   [2, 2377, 184],
#   [101, 49, 13],
#   [101, 49, 13],
#   [44, 18, 863],
#   [77, 45, 18],
#   [15, 6, 270],
#   [55, 25, 17],
#   [266, 23, 276],
#   [2, 456, 4],
#   [240, 1127, 145],
#   [38, 163, 34],
#   [101, 61, 18],
#   [23, 1342, 80],
#   [38, 662, 34],
#   [5, 12, 51],
#   [58, 1342, 80],
#   [171, 112, 274],
#   [79, 510, 14],
#   [30, 50, 320],
#   [63, 275, 217],
#   [65, 118, 76],
#   [34, 15, 473],
#   [38, 644, 34],
#   [24, 9, 1029],
#   [5, 807, 110],
#   [55, 58, 527],
#   [88, 21, 10],
#   [93, 1073, 1073],
#   [80, 87, 63],
#   [345, 44, 345],
#   [2, 456, 4],
#   [55, 91, 149],
#   [10, 287, 2100],
#   [38, 39, 191],
#   [23, 33, 389],
#   [5, 11, 41],
#   [513, 138, 145],
#   [889, 46, 1402],
#   [145, 67, 63],
#   [182, 18, 55],
#   [317, 21, 34],
#   [77, 146, 4],
#   [332, 145, 473],
#   [90, 26, 13],
#   [2632, 222, 300],
#   [34, 59, 63],
#   [202, 27, 167],
#   [1, 232, 59],
#   [58, 245, 18],
#   [745, 182, 225],
#   [1491, 601, 587],
#   [170, 12, 51],
#   [1663, 12, 345],
#   [172, 67, 63],
#   [232, 59, 1344],
#   [182, 20, 4],
#   [10, 11, 17],
#   [122, 43, 392],
#   [253, 36, 419],
#   [110, 238, 703],
#   [11, 1663, 304],
#   [2, 186, 59],
#   [5, 12, 51],
#   [52, 898, 61],
#   [10, 20, 58],
#   [52, 4, 44],
#   [38, 662, 34],
#   [238, 1289, 600],
#   [13, 29, 182],
#   [166, 312, 434],
#   [29, 52, 4],
#   [454, 21, 203],
#   [5, 13, 130],
#   [220, 491, 191],
#   [11, 972, 198],
#   [52, 3, 222],
#   [172, 15, 4],
#   [22, 4, 256],
#   [34, 270, 65],
#   [357, 58, 18],
#   [14, 20, 361],
#   [135, 490, 229],
#   [1172, 1253, 140],
#   [51, 1172, 1253],
#   [14, 244, 354],
#   [11, 67, 972],
#   [274, 229, 76],
#   [564, 3, 481],
#   [181, 6, 170],
#   [564, 3, 481],
#   [14, 23, 4],
#   [170, 34, 18],
#   [5, 247, 41],
#   [121, 269, 2184],
#   [55, 86, 11],
#   [106, 2185, 44],
#   [564, 3, 481],
#   [56, 208, 805],
#   [11, 265, 499],
#   [822, 15, 1],
#   [110, 633, 703],
#   [333, 7, 108],
#   [56, 208, 805],
#   [389, 181, 229],
#   [59, 15, 4],
#   [71, 95, 214],
#   [20, 33, 80],
#   [433, 163, 258],
#   [229, 181, 389],
#   [30, 206, 331],
#   [587, 3, 532],
#   [2, 449, 771],
#   [202, 163, 258],
#   [34, 19, 122],
#   [56, 208, 805],
#   [587, 3, 532],
#   [29, 163, 822],
#   [29, 93, 17],
#   [445, 179, 191],
#   [484, 17, 151],
#   [22, 12, 51],
#   [2153, 4, 146],
#   [2, 1106, 356],
#   [5, 11, 772],
#   [29, 179, 191],
#   [22, 12, 51],
#   [14, 643, 29],
#   [117, 3, 1404],
#   [24, 106, 196],
#   [239, 93, 17],
#   [11, 772, 191],
#   [454, 21, 18],
#   [84, 314, 58],
#   [14, 643, 29],
#   [29, 23, 4],
#   [179, 1410, 203],
#   [44, 1210, 135],
#   [56, 208, 805],
#   [24, 29, 248],
#   [22, 15, 4],
#   [11, 530, 275],
#   [2, 20, 11],
#   [38, 275, 1406],
#   [23, 33, 762],
#   [29, 248, 236],
#   [38, 275, 1406],
#   [143, 699, 214],
#   [105, 184, 107],
#   [2, 68, 81],
#   [44, 23, 33],
#   [48, 17, 715],
#   [101, 129, 598],
#   [762, 12, 51],
#   [2, 29, 3],
#   [564, 3, 481],
#   [55, 86, 11],
#   [2, 68, 81],
#   [38, 8, 4],
#   [38, 727, 34],
#   [4, 30, 184],
#   [4092, 4, 762],
#   [20, 33, 80],
#   [56, 533, 275],
#   [433, 21, 258],
#   [29, 248, 236],
#   [2, 376, 4],
#   [24, 29, 1351],
#   [320, 67, 63],
#   [31, 31, 129],
#   [11, 31, 419],
#   [44, 633, 703],
#   [1075, 316, 1582],
#   [2, 181, 108],
#   [31, 663, 145],
#   [34, 52, 154],
#   [1075, 316, 1582],
#   [19, 31, 275],
#   [622, 29, 518],
#   [38, 8, 4],
#   [8, 3, 58],
#   [134, 21, 190],
#   [134, 21, 190],
#   [121, 18, 129],
#   [2, 180, 121],
#   [101, 12, 129],
#   [44, 1771, 819],
#   [38, 34, 129],
#   [4, 181, 21],
#   [29, 1771, 819],
#   [13, 3, 266],
#   [55, 4, 11],
#   [2, 25, 33],
#   [5, 11, 41],
#   [52, 3, 154],
#   [29, 121, 154],
#   [23, 3, 154],
#   [105, 184, 107],
#   [219, 108, 63],
#   [943, 34, 18],
#   [77, 820, 4],
#   [17, 41, 1],
#   [1, 121, 11],
#   [38, 544, 34],
#   [65, 12, 54],
#   [77, 820, 19],
#   [254, 913, 398],
#   [5, 11, 18],
#   [84, 129, 29],
#   [38, 182, 391],
#   [38, 8, 4],
#   [25, 4, 9],
#   [11, 196, 419],
#   [271, 21, 190],
#   [3, 496, 989],
#   [2, 966, 502],
#   [420, 1, 310],
#   [378, 378, 378],
#   [227, 966, 502],
#   [5, 96, 148],
#   [20, 33, 275],
#   [496, 1449, 601],
#   [310, 7, 1],
#   [34, 63, 18],
#   [244, 354, 244],
#   [96, 148, 95],
#   [314, 34, 201],
#   [5, 245, 143],
#   [55, 43, 63],
#   [44, 326, 63],
#   [754, 67, 63],
#   [4, 8, 26],
#   [5, 245, 143],
#   [190, 13, 31],
#   [22, 4, 12],
#   [38, 772, 34],
#   [58, 473, 145],
#   [245, 7, 108],
#   [2, 220, 4],
#   [9, 66, 11],
#   [2, 14, 47],
#   [22, 1298, 15],
#   [5, 245, 108],
#   [239, 3, 118],
#   [52, 11, 61],
#   [592, 601, 166],
#   [99, 121, 381],
#   [239, 3, 118],
#   [631, 150, 54],
#   [16, 95, 129],
#   [22, 251, 18],
#   [234, 3, 258],
#   [592, 601, 166],
#   [99, 121, 381],
#   [94, 81, 15],
#   [234, 3, 258],
#   [811, 298, 3176],
#   [592, 601, 166],
#   [20, 146, 4],
#   [99, 121, 381],
#   [134, 31, 341],
#   [592, 601, 166],
#   [75, 33, 372],
#   [1, 10, 4],
#   [592, 592, 601],
#   [598, 820, 11],
#   [2, 417, 4],
#   [30, 560, 379],
#   [1, 10, 4],
#   [1, 161, 4],
#   [454, 21, 453],
#   [12, 34, 379],
#   [1, 10, 4],
#   [791, 3, 1213],
#   [17, 29, 18],
#   [5, 11, 338],
#   [2, 101, 17],
#   [277, 3, 170],
#   [3, 222, 401],
#   [18, 3, 1025],
#   [62, 474, 44],
#   [1213, 3, 1213],
#   [94, 87, 18],
#   [2, 14, 47],
#   [634, 3, 1213],
#   [11, 3, 1778],
#   [44, 3, 1025],
#   [30, 560, 379],
#   [79, 25, 29],
#   [38, 28, 34],
#   [312, 434, 486],
#   [1, 173, 4],
#   [38, 17, 18],
#   [195, 62, 113],
#   [62, 46, 97],
#   [88, 21, 706],
#   [5, 8, 19],
#   [56, 28, 34],
#   [23, 91, 333],
#   [38, 8, 4],
#   [54, 101, 885],
#   [23, 91, 333],
#   [22, 33, 154],
#   [66, 597, 1002],
#   [38, 2026, 2027],
#   [2905, 2905, 2905],
#   [66, 597, 1002],
#   [22, 370, 84],
#   [66, 597, 1002],
#   [83, 214, 203],
#   [58, 3, 183],
#   [54, 41, 1],
#   [65, 239, 912],
#   [34, 63, 18],
#   [305, 3, 495],
#   [106, 5, 11],
#   [468, 348, 170],
#   [66, 597, 1002],
#   [77, 820, 4],
#   [30, 560, 782],
#   [2155, 456, 4],
#   [163, 568, 21],
#   [54, 101, 885],
#   [146, 11, 718],
#   [2, 27, 7],
#   [67, 3, 676],
#   [161, 19, 252],
#   [121, 154, 18],
#   [16, 5, 132],
#   [172, 15, 1353],
#   [88, 17, 1104],
#   [2, 456, 4],
#   [5, 12, 4],
#   [22, 1458, 12],
#   [5, 245, 21],
#   [5, 8, 13],
#   [33, 1673, 1674],
#   [66, 597, 1002],
#   [428, 428, 428],
#   [66, 266, 1002],
#   [58, 22, 12],
#   [2, 14, 47],
#   [22, 1458, 12],
#   [66, 107, 644],
#   [55, 4, 54],
#   [1, 10, 4],
#   [38, 8, 4],
#   [99, 66, 145],
#   [84, 20, 33],
#   [1, 10, 4],
#   [9, 9, 9],
#   [63, 4, 8],
#   [9, 4, 58],
#   [1, 146, 4],
#   [1, 52, 61],
#   [88, 21, 232],
#   [5, 8, 13],
#   [844, 655, 18],
#   [64, 3, 232],
#   [23, 33, 1024],
#   [347, 356, 115],
#   [9, 18, 9],
#   [1, 27, 222],
#   [111, 245, 220],
#   [33, 33, 1024],
#   [123, 52, 4],
#   [2, 121, 143],
#   [91, 406, 129],
#   [38, 34, 115],
#   [33, 33, 1024],
#   [33, 33, 1024],
#   [1, 764, 4],
#   [277, 11, 43],
#   [1, 425, 4],
#   [101, 150, 41],
#   [33, 33, 1024],
#   [32, 185, 4],
#   [1, 20, 154],
#   [398, 306, 61],
#   [44, 456, 11],
#   [1458, 34, 216],
#   [95, 409, 63],
#   [24, 139, 697],
#   [30, 560, 782],
#   [30, 560, 782],
#   [29, 290, 281],
#   [2, 23, 205],
#   [277, 398, 43],
#   [143, 679, 41],
#   [113, 113, 113],
#   [14, 521, 4],
#   [2, 23, 205],
#   [824, 129, 76],
#   [867, 867, 867],
#   [305, 52, 15],
#   [18, 309, 43],
#   [77, 5, 313],
#   [56, 873, 715],
#   [129, 409, 63],
#   [66, 597, 1002],
#   [11, 430, 121],
#   [131, 37, 196],
#   [634, 248, 59],
#   [66, 597, 1002],
#   [93, 407, 13],
#   [1341, 948, 163],
#   [454, 21, 129],
#   [454, 21, 203],
#   [220, 3, 687],
#   [245, 11, 282],
#   [112, 12, 51],
#   [506, 3, 687],
#   [454, 21, 203],
#   [454, 21, 203],
#   [1, 10, 4],
#   [220, 4, 1678],
#   [918, 409, 63],
#   [38, 933, 34],
#   [125, 6, 348],
#   [153, 1, 324],
#   [190, 11, 490],
#   [2, 103, 33],
#   [454, 21, 203],
#   [5, 11, 338],
#   [66, 2390, 1002],
#   [125, 6, 348],
#   [238, 107, 58],
#   [454, 21, 203],
#   [5, 1, 254],
#   [14, 20, 4],
#   [24, 9, 63],
#   [123, 4, 1678],
#   [454, 21, 203],
#   [38, 31, 590],
#   [22, 4, 81],
#   [40, 1, 460],
#   [5, 36, 94],
#   [63, 31, 590],
#   [11, 31, 374],
#   [65, 31, 912],
#   [524, 474, 41],
#   [11, 31, 374],
#   [729, 121, 11],
#   [453, 453, 333],
#   [18, 193, 203],
#   [2, 71, 586],
#   [468, 348, 129],
#   [38, 19, 144],
#   [592, 601, 532],
#   [58, 1, 184],
#   [18, 71, 4],
#   [526, 34, 201],
#   [29, 172, 59],
#   [640, 41, 1],
#   [38, 31, 590],
#   [202, 1, 23],
#   [117, 173, 333],
#   [17, 129, 640],
#   [58, 66, 170],
#   [277, 398, 43],
#   [271, 31, 191],
#   [5, 11, 18],
#   [38, 1, 34],
#   [14, 521, 4],
#   [22, 578, 12],
#   [54, 56, 34],
#   [101, 15, 18],
#   [22, 578, 12],
#   [101, 15, 125],
#   [30, 3, 379],
#   [68, 187, 578],
#   [277, 750, 398],
#   [125, 4, 163],
#   [5, 8, 11],
#   [88, 1614, 1],
#   [103, 33, 372],
#   [34, 19, 122],
#   [1989, 1989, 1989],
#   [1, 20, 154],
#   [804, 194, 1],
#   [14, 188, 334],
#   [66, 597, 1002],
#   [5, 245, 453],
#   [29, 58, 750],
#   [65, 11, 154],
#   [1030, 15, 4],
#   [101, 24, 9],
#   [30, 3, 919],
#   [29, 190, 11],
#   [578, 12, 51],
#   [20, 65, 108],
#   [94, 4, 76],
#   [125, 4, 163],
#   [1520, 22, 447],
#   [63, 154, 18],
#   [42, 50, 130],
#   [52, 36, 170],
#   [79, 25, 143],
#   [5, 1, 110],
#   [38, 22, 226],
#   [920, 1520, 1186],
#   [1614, 129, 80],
#   [1, 117, 1520],
#   [79, 25, 143],
#   [2197, 95, 80],
#   [30, 3, 123],
#   [55, 86, 11],
#   [11, 24, 9],
#   [55, 86, 11],
#   [22, 170, 12],
#   [26, 2648, 331],
#   [183, 12, 51],
#   [139, 437, 170],
#   [3, 709, 1765],
#   [55, 55, 55],
#   [101, 82, 1355],
#   [487, 18, 157],
#   [2, 23, 17],
#   [245, 7, 349],
#   [1878, 1878, 1878],
#   [30, 3, 123],
#   [29, 10, 4],
#   [35, 27, 300],
#   [23, 3, 216],
#   [402, 3, 452],
#   [112, 390, 21],
#   [11, 3, 184],
#   [1024, 12, 51],
#   [26, 105, 34],
#   [5, 245, 1577],
#   [29, 88, 29],
#   [5, 8, 19],
#   [5, 107, 138],
#   [277, 812, 43],
#   [2, 121, 154],
#   [52, 935, 597],
#   [42, 3, 935],
#   [567, 41, 1],
#   [31, 824, 31],
#   [271, 140, 1512],
#   [305, 41, 1149],
#   [34, 12, 51],
#   [181, 29, 750],
#   [20, 34, 59],
#   [22, 198, 15],
#   [239, 3, 118],
#   [5, 11, 18],
#   [11, 3, 493],
#   [220, 4, 129],
#   [152, 37, 170],
#   [106, 67, 18],
#   [22, 15, 21],
#   [22, 183, 18],
#   [139, 437, 236],
#   [106, 139, 697],
#   [62, 191, 18],
#   [2030, 1357, 493],
#   [1, 301, 95],
#   [567, 332, 43],
#   [88, 29, 121],
#   [139, 437, 145],
#   [563, 4, 1218],
#   [2, 125, 11],
#   [188, 3, 276],
#   [38, 145, 34],
#   [88, 94, 87],
#   [563, 4, 1218],
#   [2, 125, 4],
#   [88, 29, 121],
#   [5, 2405, 110],
#   [139, 330, 567],
#   [30, 23, 593],
#   [5, 11, 18],
#   [341, 12, 51],
#   [181, 847, 18],
#   [77, 45, 18],
#   [40, 787, 274],
#   [222, 401, 807],
#   [2, 2, 58],
#   [30, 34, 43],
#   [38, 341, 29],
#   [19, 17, 87],
#   [67, 59, 54],
#   [20, 33, 11],
#   [652, 296, 567],
#   [5, 245, 7],
#   [19, 94, 87],
#   [5, 11, 18],
#   [40, 787, 274],
#   [624, 12, 51],
#   [20, 33, 11],
#   [190, 12, 1618],
#   [79, 25, 143],
#   [787, 11, 183],
#   [2, 25, 4],
#   [55, 86, 11],
#   [44, 1110, 21],
#   [22, 33, 4099],
#   [2, 26, 1],
#   [179, 471, 18],
#   [101, 15, 220],
#   [93, 17, 43],
#   [32, 700, 176],
#   [511, 220, 656],
#   [38, 66, 236],
#   [106, 95, 222],
#   [5, 37, 152],
#   [31, 665, 266],
#   [866, 12, 51],
#   [38, 36, 183],
#   [32, 32, 32],
#   [2, 192, 4],
#   [38, 36, 183],
#   [55, 1593, 10],
#   [11, 3, 1255],
#   [20, 855, 1],
#   [34, 19, 122],
#   [4100, 1267, 201],
#   [11, 3, 370],
#   [18, 71, 112],
#   [20, 855, 1],
#   [65, 3, 201],
#   [88, 21, 10],
#   [134, 21, 33],
#   [20, 855, 1],
#   [588, 12, 51],
#   [1267, 619, 834],
#   [55, 86, 11],
#   [24, 9, 715],
#   [127, 307, 115],
#   [2, 27, 58],
#   [700, 59, 63],
#   [38, 6, 183],
#   [2, 68, 391],
#   [67, 87, 63],
#   [20, 855, 1],
#   [38, 6, 183],
#   [34, 49, 353],
#   [2, 186, 59],
#   [2, 186, 59],
#   [38, 6, 183],
#   [2, 230, 112],
#   [38, 6, 183],
#   [17, 41, 125],
#   [5, 172, 59],
#   [101, 66, 236],
#   [88, 1594, 190],
#   [22, 12, 51],
#   [49, 353, 18],
#   [2, 179, 13],
#   [300, 39, 552],
#   [56, 533, 788],
#   [16, 5, 411],
#   [65, 19, 61],
#   [1, 186, 59],
#   [11, 3, 238],
#   [284, 3, 576],
#   [1, 301, 4],
#   [101, 49, 1],
#   [56, 533, 113],
#   [11, 3, 430],
#   [185, 633, 703],
#   [220, 58, 750],
#   [11, 3, 388],
#   [125, 4, 129],
#   [2, 232, 4],
#   [2, 417, 4],
#   [29, 66, 236],
#   [30, 558, 167],
#   [185, 633, 703],
#   [935, 52, 1],
#   [30, 50, 1079],
#   [5, 245, 18],
#   [935, 52, 1],
#   [5, 8, 4],
#   [185, 633, 703],
#   ...],
#  6: [[2, 29, 14, 172, 29, 435],
#   [266, 568, 21, 568, 21, 266],
#   [3, 2152, 2152, 2152, 182, 738],
#   [2, 52, 13, 911, 13, 911],
#   [5, 8, 5, 36, 12, 51],
#   [91, 163, 125, 91, 163, 125],
#   [51, 33, 1402, 34, 12, 51],
#   [18, 104, 114, 65, 1, 59],
#   [238, 703, 238, 703, 238, 703],
#   [5, 3, 245, 23, 3, 519],
#   [257, 22, 36, 222, 12, 51],
#   [2, 45, 168, 6, 183, 17],
#   [206, 331, 206, 331, 206, 331],
#   [88, 21, 23, 419, 46, 275],
#   [38, 18, 155, 159, 491, 191],
#   [91, 163, 258, 568, 21, 822],
#   [5, 11, 2579, 34, 12, 51],
#   [208, 208, 208, 208, 208, 143],
#   [2, 101, 54, 3, 168, 4],
#   [5, 1068, 1195, 26, 1068, 1195],
#   [9, 2, 14, 47, 96, 148],
#   [55, 86, 11, 145, 95, 820],
#   [10, 1, 20, 21, 52, 12],
#   [29, 22, 4, 18, 491, 191],
#   [8, 19, 34, 144, 87, 54],
#   [26, 35, 280, 280, 25, 11],
#   [88, 21, 22, 36, 214, 129],
#   [1, 20, 7, 55, 39, 215],
#   [5, 314, 10, 213, 218, 446],
#   [84, 20, 66, 66, 49, 21],
#   [24, 9, 58, 791, 65, 415],
#   [1075, 1075, 1075, 1075, 1075, 1075],
#   [38, 8, 4, 8, 4, 18],
#   [2, 20, 7, 66, 49, 19],
#   [2, 27, 101, 12, 560, 974],
#   [134, 3, 129, 239, 3, 118],
#   [10, 1, 20, 21, 65, 17],
#   [2, 27, 101, 12, 560, 379],
#   [2, 27, 188, 93, 17, 320],
#   [10, 1, 20, 21, 2153, 4],
#   [121, 106, 3, 544, 41, 1],
#   [1, 22, 4, 12, 3, 491],
#   [1, 125, 620, 405, 69, 43],
#   [9, 14, 1, 2919, 340, 4],
#   [299, 2059, 299, 2059, 299, 2059],
#   [1, 20, 125, 4, 69, 43],
#   [2, 27, 327, 19, 17, 43],
#   [226, 113, 20, 164, 19, 818],
#   [106, 3, 145, 106, 3, 145],
#   [2, 20, 7, 68, 2007, 621],
#   [88, 21, 52, 3, 475, 808],
#   [2, 27, 52, 33, 2693, 2694],
#   [18, 2, 1123, 36, 2058, 43],
#   [27, 168, 168, 3, 658, 451],
#   [2, 636, 2, 1123, 36, 2058],
#   [5, 35, 75, 15, 96, 229],
#   [18, 179, 3, 324, 7, 21],
#   [9, 22, 11, 43, 546, 29],
#   [1, 20, 7, 65, 3, 334],
#   [2, 27, 65, 4, 331, 461],
#   [2, 58, 40, 50, 1421, 1615],
#   [27, 52, 15, 11, 91, 113],
#   [378, 428, 1, 231, 460, 428],
#   [10, 134, 21, 3, 206, 17],
#   [1, 10, 4, 43, 36, 43],
#   [147, 428, 9, 958, 140, 9],
#   [2, 34, 247, 41, 128, 17],
#   [18, 92, 27, 7, 165, 18],
#   [88, 21, 66, 49, 137, 140],
#   [1, 20, 7, 68, 1500, 3386],
#   [1, 20, 7, 68, 1500, 36],
#   [2, 22, 36, 143, 258, 15],
#   [2, 27, 22, 11, 12, 51],
#   [44, 18, 5, 11, 75, 15],
#   [2, 230, 17, 59, 12, 51],
#   [10, 20, 545, 263, 12, 51],
#   [222, 196, 1453, 34, 171, 18],
#   [10, 20, 35, 280, 25, 19],
#   [64, 520, 52, 59, 78, 63],
#   [88, 21, 22, 3, 2582, 19],
#   [172, 11, 67, 38, 366, 34],
#   [88, 21, 22, 4, 15, 19],
#   [2, 103, 3, 374, 31, 362],
#   [40, 21, 117, 504, 69, 138],
#   [3388, 14, 20, 7, 34, 201],
#   [2, 207, 22, 3, 93, 863],
#   [27, 81, 27, 81, 16, 81],
#   [10, 1, 20, 21, 146, 4],
#   [16, 3, 165, 16, 3, 272],
#   [23, 62, 495, 23, 62, 495],
#   [1293, 1293, 1293, 365, 34, 18],
#   [421, 580, 356, 560, 347, 2045],
#   [24, 2, 73, 277, 4, 43],
#   [62, 156, 312, 312, 434, 486],
#   [383, 88, 21, 55, 12, 4],
#   [9, 44, 2, 230, 33, 1027],
#   [10, 1, 20, 21, 22, 167],
#   [2, 274, 1, 59, 7, 717],
#   [1, 460, 88, 21, 292, 1],
#   [2, 417, 70, 58, 3, 847],
#   [14, 10, 1, 20, 21, 563],
#   [10, 1, 20, 21, 52, 61],
#   [202, 1, 359, 68, 103, 17],
#   [631, 3, 1012, 12, 159, 1452],
#   [24, 9, 58, 25, 658, 1145],
#   [10, 1, 20, 21, 181, 445],
#   [2, 23, 3, 591, 43, 84],
#   [109, 20, 101, 81, 513, 113],
#   [10, 1, 20, 164, 181, 108],
#   [88, 21, 94, 590, 41, 1],
#   [10, 1, 20, 164, 181, 70],
#   [10, 1, 20, 21, 181, 445],
#   [2, 355, 660, 79, 25, 130],
#   [2, 2215, 172, 12, 6, 742, 238, 120, 2, 25, 742, 2041, 69, 6, 138],
#   [2, 27, 94, 4, 67, 54, 78, 35, 28, 66, 6, 199, 49, 21, 80],
#   [18, 2, 327, 31, 183, 15, 12, 36, 330, 138, 16, 12, 36, 1284, 1680],
#   [126, 2, 585, 1732, 130, 403, 21, 2, 100, 27, 7, 68, 12, 6, 1731],
#   [264, 64, 72, 155, 152, 683, 16, 22, 812, 81, 12, 54, 126, 2, 423],
#   [31, 497, 75, 513, 16, 2, 323, 31, 284, 16, 2013, 16, 130, 45, 80],
#   [2, 104, 121, 3, 148, 107, 278, 1166, 332, 201, 7, 125, 348, 49, 535],
#   [70, 14, 1, 508, 39, 135, 43, 223, 227, 71, 1, 3, 135, 93, 135],
#   [120, 2, 737, 108, 43, 25, 11, 16, 673, 108, 43, 16, 35, 73, 279],
#   [116, 103, 116, 1103, 35, 177, 164, 23, 1103, 201, 78, 35, 180, 68, 4502],
#   [79, 65, 93, 688, 743, 16, 313, 212, 4, 43, 16, 313, 342, 36, 237],
#   [14, 189, 4, 60, 223, 69, 36, 392, 101, 61, 16, 1, 72, 68, 565],
#   [242, 33, 124, 46, 212, 16, 30, 27, 7, 52, 479, 16, 479, 224, 4],
#   [42,
#    196,
#    434,
#    486,
#    1000,
#    356,
#    1950,
#    1639,
#    347,
#    2045,
#    62,
#    2955,
#    434,
#    758,
#    580],
#   [17, 896, 3, 2011, 46, 400, 49, 108, 16, 210, 2806, 4, 16, 210, 144],
#   [17, 62, 156, 166, 412, 421, 580, 312, 434, 486, 1000, 356, 1950, 1639, 347],
#   [147, 5, 10, 1, 57, 48, 8, 98, 1, 1813, 4, 15, 7, 48, 542],
#   [2, 73, 71, 36, 235, 69, 36, 122, 43, 16, 313, 4, 68, 3, 237],
#   [2, 100, 72, 71, 33, 2977, 1038, 158, 89, 127, 20, 6, 2977, 186, 76],
#   [1, 20, 7, 134, 21, 33, 354, 118, 41, 36, 128, 459, 7, 71, 33],
#   [6, 546, 138, 1, 101, 328, 48, 17, 16, 210, 327, 13, 17, 86, 201],
#   [60, 88, 21, 301, 209, 2151, 78, 2, 28, 966, 1849, 77, 350, 848, 21],
#   [16, 210, 134, 4, 7, 21, 126, 1, 423, 16, 210, 64, 72, 71, 383]],
#  21: [[54,
#    93,
#    834,
#    246,
#    59,
#    16,
#    246,
#    31,
#    2934,
#    59,
#    16,
#    49,
#    21,
#    7,
#    6,
#    2263,
#    1556,
#    168,
#    96,
#    229,
#    76],
#   [2,
#    104,
#    2601,
#    36,
#    1038,
#    59,
#    59,
#    7,
#    31,
#    31,
#    201,
#    16,
#    4264,
#    7,
#    2,
#    20,
#    3159,
#    7,
#    367,
#    12,
#    137],
#   [147,
#    18,
#    2,
#    859,
#    56,
#    141,
#    357,
#    3,
#    388,
#    3,
#    388,
#    111,
#    41,
#    569,
#    307,
#    16,
#    569,
#    72,
#    68,
#    78,
#    1872],
#   [16,
#    6,
#    17,
#    13,
#    3392,
#    64,
#    72,
#    34,
#    16,
#    64,
#    72,
#    134,
#    4,
#    3,
#    2349,
#    16,
#    30,
#    72,
#    68,
#    196,
#    84]],
#  18: [[233,
#    2,
#    207,
#    22,
#    3,
#    276,
#    78,
#    78,
#    36,
#    392,
#    180,
#    34,
#    61,
#    16,
#    301,
#    4,
#    7,
#    195],
#   [18, 53, 28, 3, 754, 52, 43, 12, 6, 392, 126, 3, 176, 8, 43, 12, 6, 392],
#   [2, 73, 2, 50, 2, 20, 1, 7, 10, 4, 41, 21, 16, 88, 21, 94, 4, 76],
#   [2,
#    23,
#    3,
#    720,
#    1990,
#    78,
#    2,
#    2530,
#    7,
#    761,
#    78,
#    106,
#    53,
#    2,
#    211,
#    3,
#    720,
#    1990],
#   [120,
#    96,
#    455,
#    1959,
#    108,
#    7,
#    328,
#    3,
#    238,
#    35,
#    581,
#    34,
#    1407,
#    132,
#    16,
#    328,
#    93,
#    238],
#   [98, 1, 155, 15, 27, 30, 72, 52, 479, 15, 48, 302, 16, 479, 15, 13, 302, 67],
#   [468,
#    92,
#    125,
#    468,
#    2302,
#    1465,
#    96,
#    760,
#    116,
#    27,
#    164,
#    52,
#    15,
#    41,
#    3,
#    206,
#    139,
#    190]],
#  17: [[3, 1474, 17, 3, 291, 17, 3, 244, 17, 1474, 17, 3, 291, 17, 3, 1474, 17],
#   [70, 8, 27, 7, 68, 3, 1066, 16, 2, 27, 7, 68, 3, 335, 7, 1205, 1],
#   [18, 40, 329, 1, 357, 21, 3, 91, 351, 1258, 78, 445, 141, 326, 15, 6, 81],
#   [56, 114, 168, 167, 313, 22, 4, 15, 54, 313, 424, 19, 313, 424, 36, 298, 61],
#   [64, 72, 22, 137, 15, 1447, 120, 89, 37, 78, 426, 2, 14, 20, 164, 1175, 137],
#   [53, 141, 1, 101, 12, 16, 313, 36, 1234, 248, 15, 4, 16, 313, 1, 101, 12],
#   [2, 14, 14, 20, 164, 161, 31, 273, 407, 9, 83, 2, 104, 161, 31, 513, 838]],
#  16: [[2, 307, 12, 6, 330, 138, 539, 16, 2, 34, 2, 307, 12, 330, 62, 1315],
#   [11, 50, 3, 1413, 646, 11, 3, 1128, 11, 3, 529, 646, 78, 56, 28, 125],
#   [2, 27, 7, 1397, 31, 175, 12, 54, 79, 25, 130, 4360, 96, 175, 12, 96],
#   [2, 27, 134, 108, 2, 27, 22, 96, 252, 2, 27, 10, 11, 7, 96, 81],
#   [120, 30, 306, 317, 34, 76, 7, 285, 1928, 7, 65, 269, 38, 7, 26, 269],
#   [1677, 35, 173, 35, 22, 3, 3, 469, 15, 6, 252, 35, 1052, 35, 735, 112],
#   [264, 6, 318, 417, 3, 135, 12, 96, 1090, 16, 36, 318, 814, 6, 135, 43],
#   [539, 18, 1138, 21, 2, 22, 15, 31, 1005, 16, 109, 364, 11, 64, 3, 318],
#   [98, 1, 88, 736, 55, 86, 4, 11, 607, 1, 14, 20, 1, 14, 25, 4],
#   [74, 670, 684, 72, 190, 15, 6, 145, 16, 56, 27, 190, 15, 670, 2587, 90],
#   [64, 72, 288, 18, 98, 109, 177, 218, 83, 400, 83, 1156, 13, 109, 611, 4551],
#   [2, 57, 2, 424, 33, 67, 12, 36, 497, 120, 2, 637, 7, 424, 12, 1644],
#   [2, 1671, 11, 272, 12, 36, 1071, 46, 36, 260, 16, 78, 1, 28, 1040, 108],
#   [2, 20, 7, 66, 49, 6, 2176, 98, 63, 112, 132, 16, 33, 46, 36, 2787],
#   [70, 11, 5, 56, 1867, 535, 7, 117, 11, 5, 56, 25, 7, 117, 14, 56],
#   [1, 207, 22, 15, 39, 4598, 223, 39, 523, 52, 761, 223, 39, 523, 52, 2896],
#   [9, 2, 100, 432, 7, 68, 12, 6, 727, 16, 6, 835, 173, 2, 100, 206]],
#  20: [[26,
#    2,
#    22,
#    131,
#    82,
#    431,
#    131,
#    217,
#    431,
#    1062,
#    43,
#    16,
#    155,
#    812,
#    16,
#    737,
#    812,
#    43,
#    12,
#    3428],
#   [126,
#    2,
#    125,
#    3,
#    2541,
#    915,
#    2,
#    185,
#    4,
#    12,
#    6,
#    578,
#    28,
#    38,
#    82,
#    269,
#    73,
#    706,
#    4,
#    115],
#   [64,
#    27,
#    7,
#    964,
#    12,
#    51,
#    16,
#    116,
#    27,
#    7,
#    55,
#    69,
#    167,
#    41,
#    21,
#    158,
#    35,
#    180,
#    26,
#    21],
#   [79,
#    36,
#    1161,
#    146,
#    16,
#    313,
#    92,
#    248,
#    61,
#    16,
#    313,
#    30,
#    987,
#    16,
#    313,
#    92,
#    34,
#    43,
#    140,
#    26]],
#  44: [[414,
#    3,
#    414,
#    3,
#    414,
#    3,
#    414,
#    3,
#    414,
#    3,
#    414,
#    3,
#    414,
#    3,
#    414,
#    3,
#    414,
#    3,
#    414,
#    3,
#    414,
#    3,
#    414,
#    3,
#    414,
#    3,
#    414,
#    3,
#    414,
#    3,
#    414,
#    3,
#    414,
#    3,
#    414,
#    3,
#    414,
#    3,
#    414,
#    3,
#    414,
#    3,
#    414,
#    3]],
#  22: [[2,
#    57,
#    2,
#    1013,
#    36,
#    136,
#    12,
#    54,
#    16,
#    313,
#    2,
#    16,
#    313,
#    36,
#    313,
#    2,
#    65,
#    408,
#    16,
#    313,
#    350,
#    61],
#   [28,
#    2,
#    22,
#    31,
#    229,
#    12,
#    36,
#    1386,
#    78,
#    36,
#    1463,
#    28,
#    47,
#    38,
#    2,
#    37,
#    16,
#    22,
#    21,
#    12,
#    6,
#    1386]],
#  19: [[98,
#    1,
#    352,
#    98,
#    1,
#    14,
#    352,
#    11,
#    64,
#    1013,
#    12,
#    54,
#    78,
#    2,
#    23,
#    205,
#    7,
#    352,
#    49],
#   [18,
#    2,
#    20,
#    6,
#    268,
#    409,
#    52,
#    19,
#    268,
#    76,
#    16,
#    22,
#    4,
#    81,
#    16,
#    23,
#    93,
#    351,
#    268],
#   [527,
#    2,
#    246,
#    1,
#    319,
#    6,
#    2370,
#    16,
#    1,
#    142,
#    68,
#    1291,
#    16,
#    1,
#    531,
#    188,
#    38,
#    39,
#    201],
#   [2, 20, 164, 26, 5, 411, 98, 1, 22, 17, 15, 63, 16, 19, 17, 15, 54, 16, 63],
#   [98,
#    1,
#    211,
#    33,
#    46,
#    31,
#    175,
#    86,
#    31,
#    157,
#    463,
#    211,
#    33,
#    46,
#    96,
#    175,
#    86,
#    31,
#    157]],
#  30: [[147,
#    64,
#    72,
#    71,
#    3,
#    295,
#    17,
#    914,
#    1271,
#    313,
#    64,
#    72,
#    165,
#    16,
#    165,
#    16,
#    165,
#    16,
#    313,
#    36,
#    2367,
#    27,
#    164,
#    1557,
#    16,
#    1557,
#    16,
#    30,
#    72,
#    117]],
#  24: [[64,
#    110,
#    17,
#    62,
#    156,
#    166,
#    412,
#    421,
#    580,
#    312,
#    434,
#    486,
#    1000,
#    356,
#    356,
#    2045,
#    1639,
#    347,
#    3262,
#    17,
#    3458,
#    2045,
#    1050,
#    76]]}

# %%
results = get_performance_bylength(seqs_bylength, maxlen)

with open(rootdir+'lstm_baseline/prod_results/'+file.split('.capp')[0]+'.prod_result.csv','w') as f :
    f.write("iter,utterance_length,nb_utterances,produced,production_score"+'\n')
    for length in results:
        f.write('1,'+str(length)+','+
                        str(results[length][1])+','+
                        str(results[length][0])+','+
                        str(results[length][0]/results[length][1])+'\n')
del g_model

# %%
seqs_bylength = get_seq_bylength(test)

# %%
results = get_performance_bylength(seqs_bylength, maxlen)
# Out:
# 2
# 3
# 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-164-7fe2207da180> in <module>
# ----> 1 results = get_performance_bylength(seqs_bylength, maxlen)
#
# <ipython-input-151-fd7fb415d34d> in get_performance_bylength(seqs_bylength, maxlen)
#      20         print(str(length))
#      21         for seq in seqs:
# ---> 22             results_bylength[length][0] += eval_production(seq, maxlen)
#      23
#      24     return results_bylength
#
# <ipython-input-141-586f505dc82e> in eval_production(seq, maxlen)
#      23
#      24     while vocab != [] :
# ---> 25         (next_word, max_prob) = max([(v, get_seq_prob(v, context, maxlen)) for v in vocab], key=lambda prob:prob[1])
#      26         context.append(next_word)
#      27         vocab.remove(next_word)
#
# <ipython-input-141-586f505dc82e> in <listcomp>(.0)
#      23
#      24     while vocab != [] :
# ---> 25         (next_word, max_prob) = max([(v, get_seq_prob(v, context, maxlen)) for v in vocab], key=lambda prob:prob[1])
#      26         context.append(next_word)
#      27         vocab.remove(next_word)
#
# <ipython-input-141-586f505dc82e> in get_seq_prob(word, context, maxlen)
#       7     y = np.array(y) - 1  # The word <PAD> does not have a class
#       8
# ----> 9     p_pred = model.predict(x)
#      10     log_p_seq = 0
#      11
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
seqs_bylength.keys()
# Out:
# dict_keys([2, 3, 6, 4, 7, 5, 8, 12, 9, 11, 10, 14, 13, 25, 15, 20, 18, 17, 19, 16, 44, 22, 21, 27, 23])

# %%
results
# Out:
# {2: [6, 7]}

# %%
model.save('test_model.h5')

# %%
rootdir = '../../data'

data = get_data_from_files(rootdir)
for file,train,test in data:
    vocab_size,maxlen,x,y = prepare_train_set(train)
    model = train_model(vocab_size,maxlen,x,y, output_size=10, epochs=10)
    model.save(str('../../trained_models/eng/'+file+'_model.h5'))
    seqs_bylength = get_seq_bylength(test)
    results = get_performance_bylength(seqs_bylength, maxlen)
    
    outputfile = open(rootdir+'lstm_baseline/prod_results/'+file.split('.capp')[0]+'.prod_result.csv','w')
    outputfile.write("iter,utterance_length,nb_utterances,produced,production_score"+'\n')
            for results in production_scores:
                for length in results:
                    outputfile.write('1,'+str(length)+','+
                                     str(results[length][1])+','+
                                     str(results[length][0])+','+
                                     str(results[length][0]/results[length][1])+'\n')
    del model
